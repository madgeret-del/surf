# %% [markdown]
# <a href="https://colab.research.google.com/github/madgeret-del/surf/blob/vibe/surf-llm-flex-fdae6c/colab/Surf_AI_Agent_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Surf AI Agent - Google Colab Demo**Computer Use AI - Control GUI with Natural Language**A flexible AI agent that converts natural language to GUI actions (click, type, scroll, etc.). Works with ANY LLM provider!---## Features- [x] Multi-Provider: OpenAI, Mistral, Anthropic, Groq, Ollama, etc.- [x] 9 Action Types: click, double_click, scroll, type, press_key, move_mouse, wait, focus, screenshot- [x] Natural Language: "Click at 100,200 and type Hello" -> generates actions- [x] Configurable: Set any base URL and API key- [x] Lightweight: Runs in Colab with minimal resources- [x] Open Source: MIT License## Quick StartRun all cells in order, or jump to specific sections below.

# %%
# Install Surf AI Agent!git clone https://github.com/madgeret-del/surf.git%cd surf!pip install -r requirements.txtprint('Surf AI Agent installed successfully!')

# %%
# Use this for easy API key input in Colabfrom google.colab import userdatatry:    api_key = userdata.get('SURF_API_KEY')    print('API key loaded from Colab secrets')except:    api_key = input('Enter your API key: ')    print('API key set')print('API key configured!')

# %%
from surf import SurfConfigimport osconfig = SurfConfig(    base_url='https://api.openai.com/v1',    api_key=api_key,    model='gpt-4o-mini',    temperature=0.7,    max_tokens=4096,    verbose=True)print('Configuration ready!')print(f'Base URL: {config.base_url}')print(f'Model: {config.model}')

# %%
from surf import SurfAgentagent = SurfAgent(config)result = agent.run('Click at coordinates 100, 200 and type Hello World')print(f'Success: {result.success}')print(f'Message: {result.message}')print(f'Actions executed: {len(result.actions_executed)}')for i, action in enumerate(result.actions_executed, 1):    print(f'  {i}. {action.action_type}: {action.params}')

# %%
providers = {    'openai': {'base_url': 'https://api.openai.com/v1', 'models': ['gpt-4o-mini', 'gpt-4']},    'mistral': {'base_url': 'https://api.mistral.ai/v1', 'models': ['mistral-large']},    'groq': {'base_url': 'https://api.groq.com/v1', 'models': ['llama3-8b', 'mixtral-8x7b']}}print('Available providers:', list(providers.keys()))

# %%
examples = [    'Click at coordinates 100, 200 and type Hello World',    'Move the mouse to 500, 300 and double-click',    'Scroll down by 100 pixels']for example in examples:    print(f'\nTesting: {example}')    result = agent.run(example)    print(f'   Actions: {len(result.actions_executed)}')    for action in result.actions_executed:        print(f'   - {action.action_type}: {action.params}')

# %%
from surf.actions import ClickAction, TypeAction, PressKeyAction, ScrollActionactions = [    ClickAction(x=100, y=200, button='left'),    TypeAction(text='Hello from programmatic actions!'),    PressKeyAction(key='Enter')]result = agent.run_actions(actions)print(f'Executed {len(result.actions_executed)} actions')

# %%
# !pip install pyngrok flaskfrom surf.web.server import appfrom pyngrok import ngrokimport threadingimport timeimport osos.environ['SURF_API_KEY'] = api_keydef run_flask():    app.run(host='0.0.0.0', port=5000)thread = threading.Thread(target=run_flask, daemon=True)thread.start()time.sleep(2)try:    public_url = ngrok.connect(5000).public_url    print(f'Web interface live at: {public_url}')    print('Keep this cell running to keep the server alive')except Exception as e:    print(f'Error: {e}')

# %%
# %cd /
